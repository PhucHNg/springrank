# %%
#load all packages before beginning
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
from scipy.sparse import *
from scipy import *
from scipy.sparse.linalg import lsqr
from numpy.linalg import solve, norm
import seaborn as sns #for ploting density dist.
import rank
# %matplotlib inline
np.random.seed(1)

# Set printing width of pandas
pd.set_option('max_columns', 150)

# %% [markdown]
# Freshwater Food Webs from Brazil
# ==========

# %%
Data = pd.read_csv('foodwebs\FoodsWeb_freshwater\WEB255.csv')

# %%
# Data.head()
# Out:
#   Angelini, R., Morais, R.J., Cattella, A.C., Resende, E.K., and Libralato, S. (2013). Aquatic food webs of the oxbow lakes in the Pantanal: A new site for fisheries guaranteed by alternated control?. Ecological Modelling, 253, pp. 82-96.  \
# 0  Pantanal Plain - Braco Morto Acima (MAC model)...
# 1                                      Phytoplankton
# 2                                        Macrophytes
# 3                                            Mammals
# 4                                            Caymans
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4       Unnamed: 5  \
# 0    Mammals    Caymans      Birds  Zooplankton  Aquatic insects
# 1          0          0          0          0.4                0
# 2          0          0          0            0              0.2
# 3          0          0          0            0                0
# 4          0          0          0            0                0
#
#             Unnamed: 6   Unnamed: 7   Unnamed: 8    Unnamed: 9   Unnamed: 10  \
# 0  Terrestrial insects  S. borellii  S. robustum  T. argenteus  C. australis
# 1                    0            0            0             0          0.04
# 2                  0.3          0.5            0          0.03             0
# 3                    0            0            0             0             0
# 4                    0            0            0             0             0
#
#       Unnamed: 11   Unnamed: 12     Unnamed: 13      Unnamed: 14  \
# 0  P. reticulatum  H. orthonops  Hypostomus spp  P. curviventris
# 1               0          0.26               0                0
# 2               0           0.7               0                0
# 3               0             0               0                0
# 4               0             0               0                0
#
#      Unnamed: 15      Unnamed: 16    Unnamed: 17       Unnamed: 18  \
# 0  P. corruscans  Moenkhausia spp  Loricaria spp  P. squamoralevis
# 1              0            0.003              0                 0
# 2              0          0.00058              0                 0
# 3              0                0              0                 0
# 4              0                0              0                 0
#
#    Unnamed: 19    Unnamed: 20  Unnamed: 21    Unnamed: 22       Unnamed: 23  \
# 0  A. nuchalis  Leporinus spp  P. ternetzi  A. pantaneiro  H. platyrhynchus
# 1            0          0.001            0              0                 0
# 2            0          0.068            0              0                 0
# 3            0              0            0              0                 0
# 4            0              0            0              0                 0
#
#         Unnamed: 24     Unnamed: 25      Unnamed: 26  Unnamed: 27  \
# 0  T. paraguayensis  H. malabaricus  Serrasalmus spp  G. balzanii
# 1             0.065               0                0        0.014
# 2                 0               0             0.02            0
# 3                 0               0                0            0
# 4                 0               0                0            0
#
#      Unnamed: 28          Unnamed: 29    Unnamed: 30           Unnamed: 31  \
# 0  Pimelodus spp  Loricariichthys spp  Roeboides spp  Steindachenerina spp
# 1              0                    0              0                 0.092
# 2              0                    0          0.076                     0
# 3              0                    0              0                     0
# 4              0                    0              0                     0
#
#    Unnamed: 32      Unnamed: 33      Unnamed: 34  Unnamed: 35
# 0  C. dorsalis  Triportheus spp  Pimelodella spp  Astyanax sp
# 1            0            0.039            0.065        0.052
# 2        0.025                0            0.022        0.057
# 3            0                0                0            0
# 4            0                0                0            0

# %%
#https://stackoverflow.com/questions/20868394/changing-a-specific-column-name-in-pandas-dataframe
Data = Data.rename(columns = {list(Data)[0]:'key'})
# Data.head()

# %%
col_names = pd.DataFrame(Data.values[0,:])
col_names.columns = ['key']
# col_names

# %%
# reorder rows and columns
ordered_data = pd.merge(col_names, Data, how='outer', on=['key'])
# ordered_data

# %%
for col in ordered_data['key'][36:]:
    ordered_data[col] = pd.Series(np.zeros(40), index=ordered_data.index)

# %%
# ordered_data

# %%
adj_matrix = ordered_data.values[1:, 1:].astype(np.float)

# %%
# ordered_data

# %%
plt.matshow(adj_matrix)
plt.show()

# %%
rank.examine_correlation(adj_matrix)

# %%
out = rank.spring_rank(adj_matrix)
scores = out[0]
Sigma = out[1]

# %%
inds = np.argsort(scores)
inds
# Out:
# array([35, 36, 38, 37,  3,  4,  5, 11,  6, 31, 30, 13, 28, 17, 16, 19,  7,
#        15, 12, 23, 27, 26,  9, 34, 32, 33,  8, 18, 29, 25, 24, 14, 21, 10,
#        22, 20,  2,  1,  0], dtype=int64)

# %%
Sigma
# Out:
# array([[ 1.24995928,  0.18877918, -0.08606259, ..., -0.09708637,
#         -0.04855322, -0.0670805 ],
#        [ 0.18877918,  1.15113749, -0.08390542, ..., -0.09696083,
#         -0.03845366, -0.06534434],
#        [-0.08606259, -0.08390542,  1.03771553, ..., -0.06348433,
#         -0.01934341, -0.02307936],
#        ...,
#        [-0.09708637, -0.09696083, -0.06348433, ...,  0.74596745,
#         -0.06102332,  0.03303042],
#        [-0.04855322, -0.03845366, -0.01934341, ..., -0.06102332,
#          0.11997974, -0.02200516],
#        [-0.0670805 , -0.06534434, -0.02307936, ...,  0.03303042,
#         -0.02200516,  0.38742524]])

# %%
ordered_Sigma = Sigma[inds,:]
ordered_Sigma = ordered_Sigma[:, inds]

# %%
plt.scatter(range(39), scores[inds]);
plt.title('Ranking of species using SpringRank')
plt.xlabel('Species')
plt.ylabel('Ranking')
plt.show()

# %%
trophic_levels = np.array([1,1,1,2,2,2,2,3.1,2,2.3,2.2,2.1,2.1,2.7,2,2.7,2.5,2.6,2.6,2.6,2.6,2.3,2.7,3.1,2.8,3.6,3.8,3.7,4,3.8,3.8,3.8,3.6,3.8,2.6,2.2,2.9,3.7,2.6,1])
trophic_levels = np.sort(trophic_levels)
plt.scatter(range(trophic_levels.size), trophic_levels);
plt.title('Trophic levels of species given in paper')
plt.xlabel('Species')
plt.ylabel('Trophic level')
plt.show()

# %%
PCorrel = rank.pearson_correlation(ordered_Sigma)
plt.matshow(PCorrel, cmap='hot', vmin=-0.2, vmax=0.4)
plt.colorbar()

# %%
ordered_data['key'][inds]
# Out:
# 0     Pantanal Plain - Braco Morto Acima (MAC model)...
# 1                                               Mammals
# 2                                               Caymans
# 20                                        Leporinus spp
# 22                                        A. pantaneiro
# 10                                         C. australis
# 21                                          P. ternetzi
# 14                                      P. curviventris
# 24                                     T. paraguayensis
# 25                                       H. malabaricus
# 29                                  Loricariichthys spp
# 18                                     P. squamoralevis
# 8                                           S. robustum
# 33                                      Triportheus spp
# 32                                          C. dorsalis
# 34                                      Pimelodella spp
# 9                                          T. argenteus
# 26                                      Serrasalmus spp
# 27                                          G. balzanii
# 23                                     H. platyrhynchus
# 12                                         H. orthonops
# 15                                        P. corruscans
# 7                                           S. borellii
# 19                                          A. nuchalis
# 16                                      Moenkhausia spp
# 17                                        Loricaria spp
# 28                                        Pimelodus spp
# 13                                       Hypostomus spp
# 30                                        Roeboides spp
# 31                                 Steindachenerina spp
# 6                                   Terrestrial insects
# 11                                       P. reticulatum
# 5                                       Aquatic insects
# 4                                           Zooplankton
# 3                                                 Birds
# 37                                          Macrophytes
# 38                                             Detritus
# 36                                        Phytoplankton
# 35                                          Astyanax sp
# Name: key, dtype: object

# %% [markdown]
# Looks somewhat similar to the rankings predicted with SpringRank in terms of
# shift in levels, though the rankings within are a lil different.
