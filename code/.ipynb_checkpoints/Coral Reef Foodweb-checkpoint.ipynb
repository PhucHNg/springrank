# %% [markdown]
# Corel Reef Foodweb
# ========
#
# Questions:
#
# - If I cluster things, the algorithms will always produce clusters. How do I check that those clusters are "good"?

# %%
import numpy as np
from numpy.linalg import solve, norm
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
import rank
# %matplotlib inline
np.random.seed(1)

#Set printing width of pandas
pd.set_option('max_columns', 150)

# %%
#Load data Cayman Island
#Matrix, rows are predators, columns are preys.

Data = pd.read_csv('..\\data\\foodweb\\Coral reef\\857470.item.5.dat', sep='\s+', header=None)
Meta_data = pd.read_excel('..\\data\\foodweb\\Coral reef\\857470.item.1.xlsx')

# %%
A = np.loadtxt('..\\data\\foodweb\\Coral reef\\857470.item.5.dat', dtype=float) #adjacency matrix

# %%
#Don't do this: for example, row 1 is empty but column 1 is not.
#Remove empty rows and columns
#https://stackoverflow.com/questions/11188364/remove-zero-lines-2-d-numpy-array

# inds_remove = np.arange(0,265)[np.all(A==0, axis=1)]
# ids = np.delete(np.arange(1,266), inds_remove, axis=0)
# A = np.delete(np.delete(A, inds_remove, axis=1), inds_remove, axis=0)

# %%
#SpringRank scores and clusters

scores, sigma = rank.spring_rank(A)
correlation = rank.pearson_correlation(sigma)


#Take a look at the matrix to see if there are clusters?

inds_sort = np.argsort(scores)
scores = scores[inds_sort]
correlation = correlation[inds_sort,][:,inds_sort]
plt.matshow(correlation, cmap='RdBu_r')
plt.colorbar()

# %%
#Plot ranking density plot

from scipy.stats import norm
from sklearn.neighbors import KernelDensity

X = scores[:, np.newaxis]
X_plot = np.linspace(np.min(X), np.max(X), 1000)[:, np.newaxis]
fig, ax = plt.subplots()
kde = KernelDensity(kernel='gaussian', bandwidth=0.5).fit(X)
log_dens = kde.score_samples(X_plot) 
ax.plot(X_plot[:, 0], np.exp(log_dens), '-',
        label="kernel = '{0}'".format('gaussian'))

# %%
TODo:
    -Is the ranking we find statistically significant.
    -Percentage of violation
    -The

# %% [markdown]
# I can't really see "communities" in this heatmap of the correlation or the density of the scores.

# %% [markdown]
# Maybe, I can check if the forced communities are actually meaningful?
#
# Clusters
# ----------

# %%
from sklearn.cluster import KMeans

n_clusters = 3

#Using the scores

kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(scores.reshape((scores.size,1)))
clusters0 = kmeans.labels_

#Using the correlation

kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(correlation)
clusters1 = kmeans.labels_

# %% [markdown]
# Save network for viz in Gephi
# ---------------
#
# edges.csv
#
# - Target: id of nodes
# - Source: id of nodes
# - All edges have weight 1
#
# nodes.csv
#
# - id: guild numbers
# - cluster1: community given by SR scores
# - cluster2: community given by SR correlations
# - ranks: scores given by SR
# - description: guild description in common language
# - habitat: foraging habitat
# - prey_number: number of guilds containing preys
# - preys: list of preys

# %%
#Create edges.csv file
#Find the indices of non-zero elements in adjacency matrix

cols = Data.columns
bt = Data.apply(lambda x: x > 0) #return T, F data frame
temp = bt.apply(lambda x: list(cols[x.values]), axis=1) #return lists of targets 
l = 3766 #number of edges
Source = np.zeros(l)
Target = np.zeros(l)
current_index = 0
for i in range(0,265):
    new_index = current_index + len(temp[i])
    Target[current_index: new_index] = temp[i]
    Source[current_index: new_index] = i
    current_index = new_index
Target = Target+1.0
Source = Source+1.0

#Note: would have been easier to do this after importing .dat file as numpy matrix

# %%
#Save the edges in csv file
np.savetxt('cayman_edges.csv', np.dstack((Source, Target))[0], delimiter=',', header=("Source, Target"))

# %%
#Create nodes.csv file

d = {"Guild Number": np.arange(1,266), "cluster1": clusters0, "cluster2": clusters1, "ranks": scores}
SR_data = pd.DataFrame(data=d)
Nodes_data = SR_data.merge(Meta_data.dropna(), on="Guild Number", how="inner", suffixes=("_sr","_meta"))
Nodes_data.head(10)
# Out:
#   Guild Number  cluster1  cluster2     ranks              Guild Description  \
# 0            1         2         0 -1.734984            Planktonic bacteria
# 1            2         2         2 -1.465477                  Phytoplankton
# 2            3         2         1 -1.449378              Nanno-zooplankton
# 3            5         2         1 -1.412683               Sheet macroalgae
# 4            6         2         0 -1.348871   Coarsely branched macroalgae
# 5            7         2         1 -1.167036  Jointed calcareous macroalgae
# 6            8         2         0 -1.165852      Thick leathery macroalgae
# 7            9         2         2 -1.144088       Crustose coralline algae
# 8           10         2         0 -1.132797                     Seagrasses
# 9           11         2         2 -1.132369             Epibenthic sponges
#
#   Foraging Habitat  Number of Prey  Prey
# 0                .             0.0     .
# 1                .             0.0     .
# ...

# %%
#Merge with nodes.csv from Gephi

Gephi_data = pd.read_csv('..\\data\\foodweb\\Coral reef\\gephi_cayman_nodes.csv')
Nodes_data1 = Nodes_data.merge(Gephi_data, on="Guild Number", how="right", suffixes=("_l", "_r"))
# Nodes_data1 = Nodes_data1.drop(["Guild Number_l", "Guild Number_r"], axis=1)
Nodes_data1.head(10)
# Out:
#    Guild Number  cluster1  cluster2     ranks              Guild Description  \
# 0           1.0       2.0       0.0 -1.734984            Planktonic bacteria
# 1           2.0       2.0       2.0 -1.465477                  Phytoplankton
# 2           3.0       2.0       1.0 -1.449378              Nanno-zooplankton
# 3           5.0       2.0       1.0 -1.412683               Sheet macroalgae
# 4           6.0       2.0       0.0 -1.348871   Coarsely branched macroalgae
# 5           7.0       2.0       1.0 -1.167036  Jointed calcareous macroalgae
# 6           8.0       2.0       0.0 -1.165852      Thick leathery macroalgae
# 7           9.0       2.0       2.0 -1.144088       Crustose coralline algae
# 8          10.0       2.0       0.0 -1.132797                     Seagrasses
# 9          11.0       2.0       2.0 -1.132369             Epibenthic sponges
#
#   Foraging Habitat  Number of Prey  Prey
# 0                .             0.0     .
# ...

# %%
#Save nodes information in csv file
Nodes_data1.to_csv("cayman_nodes.csv")

# %% [markdown]
# Significance test of ranks
# --------

# %%
rank.summary(A, data_name="Corel Reef", data_type="foodweb")
# Out:
# ('Corel Reef', 'foodweb', 265, 0.051462379788702058, 3.1776110268642412, 0.0)

# %%
rank.test_ranks_significance(A, plot=True)
# Out:
# 0.0

# %% [markdown]
# There is definitely hierarchy in this foodweb data...
#
# Let's look at the descriptions for guilds in these different groups. Maybe there is nothing :^(

# %%
Cayman = pd.read_csv('..\\data\\foodweb\\Coral reef\\cayman_nodes.csv')
Cayman = Cayman.to_frame()
Cayman['cluster1'] = Cayman['cluster1'].astype(object)
Cayman['cluster2'] = Cayman['cluster2'].astype(object)
Cayman.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-d31a3cbcd46f> in <module>()
#       1 Cayman = pd.read_csv('..\\data\\foodweb\\Coral reef\\cayman_nodes.csv')
# ----> 2 Cayman.dtypes()
#       3 Cayman['cluster1'] = Cayman['cluster1'].astype(object)
#       4 Cayman['cluster2'] = Cayman['cluster2'].astype(object)
#       5 Cayman.head()
#
# TypeError: 'Series' object is not callable

# %%
Cayman_by_cluster2 = Cayman.groupby('Foraging Habitat')
Cayman_by_cluster2['cluster2'].describe()
# Out:
#                   count      mean       std  min  25%  50%   75%  max
# Foraging Habitat
# .                 103.0  1.019417  0.791878  0.0  0.0  1.0  2.00  2.0
# g                  22.0  0.818182  0.852803  0.0  0.0  1.0  1.75  2.0
# r                  72.0  0.652778  0.753578  0.0  0.0  0.0  1.00  2.0
# rg                 38.0  0.815789  0.833594  0.0  0.0  1.0  1.75  2.0

# %% [markdown]
# Questions
# ----
#
# 1. Why number of prey larger than list of prey? So one species may be in several guilds?
