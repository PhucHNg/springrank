# %%
import rank
import numpy as np
import scipy.sparse
import matplotlib.pyplot as plt

# %%
A = np.array([[0,2,1],
             [0,0,1],
             [1,0,0]])
A_sparse = scipy.sparse.csr_matrix(A)

# %%
print(rank.summary(A, data_name='Test', data_type='test'))
# Out:
# {'Data name': 'Test', 'Data type': 'test', 'N': 3, 'Energy per edge': 0.40000000000000002, 'Depth': 0.49999999999999978, 'p-value': 0.52000000000000002, 'Viol.': 1, '% Viol.': 0.20000000000000001, 'Min. Viol.': 0, 'Weighted viol.': 1.0}

# %%
rank.spring_rank_sparse(A)

# %%
rank.test_ranks_significance(A, n_repetitions=100, plot=True)
# Out:
# 0.0

# %%
labels = ['aa', 'bb', 'cc']
community = [1,2,3]
scores, correlation = rank.spring_rank(A)
rank.plot(correlation=correlation, scores=scores, labels=labels, community=community)
# Out:
# Note: Nodes are ordered by scores (increasing) in orrelation matrix
